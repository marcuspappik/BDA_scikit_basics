# %%
import numpy
import matplotlib.pyplot as plt

# %%
#create data
gaussian_numbers = numpy.random.normal(size=10000)

#histogramm with 20 bins
plt.hist(gaussian_numbers, 20)
plt.title("Gaussian Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()
