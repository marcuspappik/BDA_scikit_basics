# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import math
import random

# %%
steps = range(0, 50)
x1 = np.array([(1/10) * k * math.pi for k in steps])
y1 = np.sin(x)*np.exp(x**(1/2))

x2 = (1+np.array(steps))*(1/10)
y2 = np.exp(x2)

# %%
plt.plot(x1, y1, 'r')
plt.plot(x1, -y1, 'go')
plt.show()

# %%
plt.plot(x2, y2, 'ro')
plt.title('linear y axis')
plt.grid(True)
plt.ylabel('y')
plt.ylabel('x')
plt.show()

plt.plot(x2, y2, 'b^')
plt.title('log y axis')
plt.yscale('log')
plt.ylabel('also x')
plt.ylabel('also y')
plt.grid(True)
plt.show()
