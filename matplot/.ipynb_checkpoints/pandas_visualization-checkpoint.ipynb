# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.array(range(50))
y1 = (2*np.array(x) - 25) - np.random.randint(-20, 20, 50)
y2 = (2*np.array(x) - 25)
df_plot = pd.DataFrame({'X': x, 'Y1': y1, 'Y2': y2})
df_plot.plot()
plt.show()

# %%
df_plot.loc[:, 'Xsq'] = x**2
df_plot.plot(x = 'Xsq', y = 'Y1')
plt.show()

# %%
df_plot.loc[:,'Y1dif'] = df.loc[:,'Y1'] - df.loc[:,'B']
df.loc[:,'C'].plot(kind='bar')
print(df.C)
plt.show()
# Out:
# 0     14.0
# 1     15.5
# 2     14.0
# 3     14.5
# 4     12.0
# 5      4.5
# 6     10.0
# 7      9.5
# 8     13.0
# 9     12.5
# 10    16.0
# 11     4.5
# 12     7.0
# 13     9.5
# 14     2.0
# 15     0.5
# 16     1.0
# 17    10.5
# 18     9.0
# 19     3.5
# 20    -1.0
# 21    -1.5
# 22     3.0
# 23     3.5
# 24     3.0
# 25    -0.5
# 26    -2.0
# 27    -0.5
# 28    -4.0
# 29    -5.5
# 30    -6.0
# 31    -3.5
# 32     2.0
# 33    -5.5
# 34    -8.0
# 35     2.5
# 36   -13.0
# 37   -13.5
# 38    -5.0
# 39    -2.5
# 40    -5.0
# 41    -4.5
# 42    -7.0
# 43   -11.5
# 44    -3.0
# 45   -11.5
# 46   -13.0
# 47   -17.5
# 48    -9.0
# 49   -11.5
# Name: C, dtype: float64
