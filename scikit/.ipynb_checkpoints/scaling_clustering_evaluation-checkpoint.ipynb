# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('cluster_dens.csv')

# %%
plt.plot(df.x, df.y, 'ro')
plt.show()

# %%
X = StandardScaler().fit_transform(df)
plt.plot(np.transpose(X)[0], np.transpose(X)[1], 'ro')
plt.show()

# %%
dbscan = DBSCAN(eps = 0.1, min_samples = 20)

# %%
dbscan = dbscan.fit(X)

# %%
df['label'] = dbscan.labels_

# %%
cmap = cm.get_cmap('Spectral')
for label in set(dbscan.labels_):
    to_plot = df.loc[df.label == abel, :]
    plt.plot(to_plot.x, to_plot.y, color = cmap(label/len(set(dbscan.labels_))))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-f0958d57dda7> in <module>()
# ----> 1 cmap = get_cmap('Spectral')
#       2 for label in set(dbscan.labels_):
#       3     to_plot = df.loc[df.label ==label, :]
#       4     plt.plot(to_plot.x, to_plot.y, color = cmap(label/len(set(dbscan.labels_))))
#       5
#
# NameError: name 'get_cmap' is not defined
